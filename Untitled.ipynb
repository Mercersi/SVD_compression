# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import time

from PIL import Image

# %%
img = Image.open('edir.jpg')
imggray = img.convert('LA')
plt.figure(figsize=(9, 6))
plt.imshow(img);

# %%
imgmat = np.array(list(imggray.getdata(band=0)), float)
imgmat.shape = (imggray.size[1], imggray.size[0])
imgmat = np.matrix(imgmat)
plt.figure(figsize=(9,6))
plt.imshow(imgmat,cmap='gray');

# %%
U, sigma, V = np.linalg.svd(imgmat)

# %%
reconstimg = np.matrix(U[:, :1]) * np.diag(sigma[:1]) * np.matrix(V[:1, :])
plt.imshow(reconstimg,cmap='gray');

# %%
for i in range(2, 4):
    reconstimg = np.matrix(U[:, :i]) * np.diag(sigma[:i]) * np.matrix(V[:i, :])
    plt.imshow(reconstimg,cmap='gray')
    title = "n = %s" % i
    plt.title(title)
    plt.show()

# %%
for i in range(5, 101, 5):
    reconstimg = np.matrix(U[:, :i]) * np.diag(sigma[:i]) * np.matrix(V[:i, :])
    plt.imshow(reconstimg, interpolation='nearest',cmap='gray')
    title = "n = %s" % i
    plt.title(title)
    plt.show()

# %%
imgmat = np.array(list(imggray.getdata(band=0)), float)
imgmat.shape = (imggray.size[1], imggray.size[0])
imgmat = np.matrix(imgmat,cmap='gray')
plt.figure(figsize=(9,6))
plt.imshow(imgmat,cmap='gray');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-29d522c5f9e9> in <module>
#       1 imgmat = np.array(list(imggray.getdata(band=0)), float)
#       2 imgmat.shape = (imggray.size[1], imggray.size[0])
# ----> 3 imgmat = np.matrix(imgmat,cmap='gray')
#       4 plt.figure(figsize=(9,6))
#       5 plt.imshow(imgmat,cmap='gray');
#
# TypeError: __new__() got an unexpected keyword argument 'cmap'
